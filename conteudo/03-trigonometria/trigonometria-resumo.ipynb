# %% [markdown]
# <h1 align="center">Trigonometria - Resumo</h1>
#
# <h4 align="center">Prof. Eduardo Ono</h4>

# %%
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = [6, 4]

# %% [markdown]
# Seja $ABC$ um triângulo retângulo tal que os lados $\overline{BC} \,$, $\overline{AC} \,$ e $\overline{AB} \,$ possuem as medidas $m(\overline{BC}) = a \,$, $m(\overline{AC}) = b \ $ e $\ m(\overline{AB}) = c \ $ e os ângulos internos $\ \alpha = \hat{A} =  = 90\degree \,$, $\hat{B} = \beta \,$ e $\, \hat{C} = \gamma \,$, cujos .

# %% [markdown]
# ## Funções Trigonométricas

# %% [markdown]
# A Função Seno

# %%
import numpy as np
import math

x_values = []
y_values = []
for x in np.arange(-4*math.pi, 4*math.pi, 0.1):
    x_values.append(x)
    y_values.append(math.sin(x))

plt.axhline(y=0.0, color='grey', linestyle='-', linewidth=1)
plt.axvline(x=0.0, color='grey', linestyle='-', linewidth=1)
plt.plot(x_values, y_values)
plt.show()

# %% [markdown]
# ## Equações Trigonométricas
