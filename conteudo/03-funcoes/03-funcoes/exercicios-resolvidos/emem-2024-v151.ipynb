# %% [markdown]
# __ENEM-2024-v151__. &nbsp; Um artesão utiliza dois tipos de componentes, $X$ e $Y$, nos enfeites que produz. Ele sempre compra todos os componentes em uma mesma loja. O quadro apresenta os preços dos dois tipos de componentes nas lojas $\text{I}$ e $\text{II}$.
#
# <h4 align="center">
#
#  ![image.png](attachment:image.png)
#
#  </h4>
#
# &emsp; Ele confeccionará enfeites formados por duas unidades do componente $X$ e uma unidade do componente $Y$ e efetuará a compra na loja que oferecer o menor valor total para a confecção de um enfeite.
#
# &emsp; O artesão efetuará a compra na loja
#
# A) &nbsp; $\text{I}$, pois o valor é $\text{R\$ 7,00}$. &nbsp;&check;<br>
# B) &nbsp; $\text{I}$, pois o valor é $\text{R\$ 4,00}$.<br>
# C) &nbsp; $\text{II}$, pois o valor é $\text{R\$ 6,00}$.<br>
# D) &nbsp; $\text{I}$, pois anuncia o componente com o menor preço.<br>
# E) &nbsp; $\text{II}$, pois o componente X, que é o mais utilizado, tem
# menor preço.
