# %% [markdown]
# __ENEM-2023-v154__. &nbsp; Um investidor iniciante observou o gráfico que apresenta a evolução dos valores de duas criptomoedas $\text{A}$ e $\text{B}$ em relação ao tempo.
#
# ![image.png](attachment:image.png)
#
# &emsp; Durante horas consecutivas, esses valores foram observados em nove instantes, representados por horas
# exatas. Em quantos desses instantes a criptomoeda $\text{A}$ estava mais valorizada do que a criptomoeda $\text{B}$?
#
# A) $\,3$<br>
# B) $\,4$ &check;<br>
# C) $\,6$<br>
# D) $\,7$<br>
# E) $\,9$<br>

# %% [markdown]
# __RESOLUÇÃO__
#
# &emsp; Traçar a reta identidade e tomar todos os pontos à direita da reta.

# %% [markdown]
# __REFERÊNCIAS__
#
# * <https://download.inep.gov.br/enem/provas_e_gabaritos/2023_PV_impresso_D2_CD12.pdf#page=22>
