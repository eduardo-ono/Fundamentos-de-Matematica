# %% [markdown]
# __exr-2021-06-07__. &nbsp;
#
# $$
# \left \{
#   \begin{array}{rcrcl}
#   x & + & 4y & + & 3z & = & 1 \\
#   2x & + & 5y & + & 4z & = & 4 \\
#   x & + & -3y & + & -2z & = & 5
#   \end{array}
# \right.
# $$
#
# &emsp; Usando o método da eliminação de Gauss (Escalonamento), a matriz aumentada é dada por:
#
# $$
# \left [
# \begin{array}{rrr:r}
# 1 & 4 & 3 & 1 \\
# 2 & 5 & 4 & 4 \\
# 1 & -3 & -2 & 5
# \end{array}
# \right ]
# $$
#
# $$
# \left [
# \begin{array}{rrr:r}
# 1 & 4 & 3 & 1 \\
# 0 & 3 & 2 & -2 \\
# 0 & 7 & 5 & -4
# \end{array}
# \right ]
# \begin{array}{l}
# \\
# \quad L_2 \leftarrow 2L_1 - L2 \\
# \quad L_3 \leftarrow L_1 - L3
# \end{array}
# $$
#
# $$
# \left [
# \begin{array}{rrr:r}
# 1 & 4 & 3 & 1 \\
# 0 & 3 & 2 & -2 \\
# 0 & 0 & -1 & -2
# \end{array}
# \right ]
# \begin{array}{l}
# \\
# \\
# \quad L_3 \leftarrow 7L_2 -3 L3
# \end{array}
# $$
#
# $$
# \text{(III)}: \quad -z = -2 \implies \boxed{z = 2} \\
# \text{(II)}: \quad 3y + 2z = -2 \implies 3y + 2 \cdot 2 = -2 \implies 3y = -6 \implies \boxed{y = -2} \\
# \text{(I)}: \quad x + 4y + 3z = 1 \implies x + 4 \cdot (-2) + 3 \cdot 2 = 1 \implies x - 8 + 6 = 1 \implies \boxed{x = 3} \\
# $$
