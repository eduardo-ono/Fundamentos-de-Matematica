# %% [markdown]
# <h4>
#
# $$
# \text{---\{ Proporcionalidades \}---}
# \\[24pt]
# $$
#
# </h4>
#
# <h3>
#
# $$
# \text{Teorema da Bissetriz}
# $$
#
# </h3>
#
# $$
# \text{Prof. Eduardo Ono}
# \\[24pt]
# $$

# %% [markdown]
# ---

# %% [markdown]
# **Sumário**<a id='toc0_'></a>
# - 1. [Objetivos](#toc1_)
# - 2. [Teoremas da Bissetriz](#toc2_)
#   - 2.1. [Teorema da Bissetriz Interna](#toc2_1_)
#
# <!-- vscode-jupyter-toc-config
# 	numbering=true
# 	anchor=true
# 	flat=false
# 	minLevel=1
# 	maxLevel=5
# 	/vscode-jupyter-toc-config -->
# <!-- THIS CELL WILL BE REPLACED ON TOC UPDATE. DO NOT WRITE YOUR TEXT IN THIS CELL -->

# %% [markdown]
# ---

# %% [markdown]
# # 1. <a id='toc1_'></a>[Objetivos](#toc0_)
#
# - Conceituar o Teorema da Bissetriz;
#
# - Enunciar e demonstrar o Teorema da Bissetriz;
#
# - Aplicar os conceitos na resolução de problemas.

# %% [markdown]
# # 2. <a id='toc2_'></a>[Teoremas da Bissetriz](#toc0_)

# %% [markdown]
# Se duas retas são transversais de um feixe de retas paralelas, então a razão
# entre dois segmentos quaisquer de uma delas é igual à razão entre os respectivos
# segmentos correspondentes da outra.

# %% [markdown]
# ## 2.1. <a id='toc2_1_'></a>[Teorema da Bissetriz Interna](#toc0_)
#
# Uma __bissetriz interna__ de um triângulo divide o lado oposto em segmentos (aditivos) proporcionais aos lados adjacentes.

# %% [markdown]
# O enunciado acima deve ser entendido como segue.
#
# Dado um triângulo $ABC$ de lados $a$, $b$ e $c$, $\,\overline{AB}\,$ uma bissetria interna, $\,\overline{BD} = m\,$, $\,\overline{DC} = n\,$, devemos ter:
#
# $$
# \boxed{\ \cfrac{\,m\,}{c} = \cfrac{\;n\;}{b}\ }
# $$
#
# Demonstração.
#
# Hipótese: $\overline{AD}$ é bissentriz interna do $\triangle ABC$.
#
# Tese: $\cfrac{\,m\,}{c} = \cfrac{\;n\;}{b}$
#
# | |
# | :-: |
# | ![teorema-da-bissetriz-interna.png](attachment:teorema-da-bissetriz-interna.png) |
# | Fonte: Iezzi |
#
# Conduzimos por $C$ uma paralela à bissetriz $\,\overline{AD}\,$, determinando um ponto $E$ na reta $\,\overleftrightarrow{AB}\,$, de modo que $\,\overline{CE}\, /\negmedspace/\, \overline{AD}\,$.
#
# Os ângulos $\,B\hat{A}D\,$ e $\,A\hat{E}C\,$ são correspondentes e os ângulos $\,D\hat{A}C\,$ e $\,A\hat{C}E\,$ são alternos internos. Por hipótese, os ângulos $\,B\hat{A}D\,$ e $\,D\hat{A}C\,$ são congruentes. Decorre que os ângulos $\,A\hat{E}C\,$ e $\,E\hat{C}A\,$ são congruentes, caracterizando o triângulo $ACE$, de base $\,\overline{CE}\,$, como isósceles. Temos, então:
#
# $$
# \overline{AC} \equiv \overline{AE}\,.
# $$
#
# Aplicando o teorema de Tales, vem:
#
# $$
# \cfrac{\overline{BD}}{\overline{BA}} = \cfrac{\overline{DC}}{\overline{AE}} \implies \cfrac{\overline{BD}}{\overline{BA}} = \cfrac{\overline{DC}}{\overline{AC}} \\
# $$
#
# Portanto,
#
# $$
# \boxed{\cfrac{\ m\ }{\ c\ } = \cfrac{\ n\ }{\ b\ }\,}.
# $$
