# %% [markdown]
# <sup>Fundamentos de Matemática</sup>
# <img alt="" width="100%" height="2px" align="right">
#
# &nbsp;
#
# <h1 align="center">Resumo &ndash; Geometria Espacial</h1>
# <h4 align="center">Prof. Eduardo Ono</h4>
# <h6 align="center">Atualizado em: 23/05/2025</h6>
#
# <h6 align="center"><a href="https://nbviewer.org/github/eduardo-ono/Fundamentos-de-Matematica/blob/main/conteudo/12-geometria-espacial/resumo-geometria-espacial.ipynb">Versão para impressão</a></h6>
#
# &nbsp;

# %% [markdown]
# <hr>
#
# # Pirâmides
#
# | Propriedade | | |
# | --- | :-: | :-: |
# | Volume | $V = \cfrac{1}{3} \, A_{\text{base}} \cdot H$ | |
# | Área superficial | $$ | |
# | Relações de<br>semelhança | $h' = H - h$<br>$\cfrac{h'}{H} =\cfrac{\ell}{L}$<br><br>$\Big(\cfrac{h'}{H}\Big)^2 = \cfrac{A_b}{A_B}$<br><br>$\Big(\cfrac{h'}{H}\Big)^3 = \cfrac{V'}{V}$ | ![image.png](attachment:image.png) |
# | Volume do tronco | $V = \cfrac{h}{3} \left( A_b + \sqrt{A_b \cdot A_B} + A_B \right)$ | ![image-2.png](attachment:image-2.png) |

# %% [markdown]
# <hr>
#
# # Cilindros
#
# | Propriedade | |
# | --- | --- |
# | Volume | $V = A_{\text{base}} \cdot h = \pi r^2 h$ |
# | Área superficial | $A_T = 2 \pi r^2 + 2 \pi r h$ |

# %% [markdown]
# <hr>
#
# # Cones
#
# | Propriedade | Dedução | |
# | --- | :-: | :-: |
# | Elementos | | ![image.png](attachment:image.png) |
# | Volume | $V = \cfrac{1}{3} \, A_{\text{base}} \cdot h$ | $V = \cfrac{1}{3} \, \pi r^2 h$ |
# | Área da base | = Área do círculo de raio $r$ | $A_{\text{base}} = \pi r^2$ |
# | Área lateral<br>(setor circular) | $\cfrac{\pi r^2}{2 \pi r} = \cfrac{A_L}{2 \pi g}$ | $A_L = \pi r g$ |

# %% [markdown]
# <hr>
#
# # Esfera
#
# | Propriedade | Dedução | | |
# | --- | :-: | :-: | :-: |
# | Elementos | | ![image.png](attachment:image.png) | |
# | Volume | | $V = \cfrac{4}{3} \, \pi r^3$ | [![img](https://img.youtube.com/vi/RwMQRmiYvvw/default.jpg)](https://www.youtube.com/watch?v=RwMQRmiYvvw) |
# | Área superficial | $\cfrac{4}{3} \, \pi r^3 = \cfrac{1}{3} A_{b_1} h + \cfrac{1}{3} A_{b_2} h + \cdots + \cfrac{1}{3} A_{b_n} h$<br><br>$\cfrac{4}{3} \, \pi r^3 = \cfrac{1}{3} \, h \left(A_{b_1} + A_{b_2} + \cdots + A_{b_n}\right)$<br>$n \to \infty \implies h \to r \quad \text{e} \quad \left(A_{b_1} + A_{b_2} + \cdots + A_{b_n}\right) \to A_s$<br>$\cfrac{4}{3} \, \pi r^3 = \cfrac{1}{3} \, r A_s$ | $A_s = 4 \pi r^2$ | [![img](https://img.youtube.com/vi/pBOEtCh7vj0/default.jpg)](https://www.youtube.com/watch?v=pBOEtCh7vj0) |
# | Fuso | | ![image-2.png](attachment:image-2.png) | [![img](https://img.youtube.com/vi/gA6dMFpvcgY/default.jpg)](https://www.youtube.com/watch?v=gA6dMFpvcgY) |
# | Cunha | | | [![img](https://img.youtube.com/vi/gA6dMFpvcgY/default.jpg)](https://www.youtube.com/watch?v=gA6dMFpvcgY) |
