# %% [markdown]
# (Unicamp 2026) &nbsp; $\theta = \cfrac{2}{3}$, o valor da área do triângulo é
#
# ![image.png](attachment:image.png)
#
#
# a) 2<br>
# b) 1<br>
# c) 3<br>
# d) nenhum
#
# &emsp;&emsp; *Dica extra: Utilize $\,\text{tg}\,\Big(\cfrac{\theta}{2}\Big) = \pm\sqrt{\cfrac{1 - \cos{\theta}}{1 + \cos{\theta}}}\,$.

# %% [markdown]
# ![image.png](attachment:image.png)
#
# $$
# \text{tg}\,{\alpha} = \pm\sqrt{\cfrac{1 - \cos{\theta}}{1 + \cos{\theta}}}
# $$

# %% [markdown]
# $$
# \text{tg}\,{\alpha} = \pm\sqrt{\cfrac{1 - \cfrac{2}{3}}{1 + \cfrac{2}{3}}} = \pm\sqrt{\,\cfrac{\cfrac{\,1\,}{3}}{\cfrac{\,5\,}{3}}\,}
# $$
#
# $$
# \text{tg}\,{\alpha} = \pm\sqrt{\cfrac{1}{5}} = \cfrac{1}{\sqrt{5}}
# $$
#
# $$
# \cfrac{b/2}{x} = \cfrac{1}{\sqrt{5}}
# $$
#
# $$
# b = \cfrac{2x}{\sqrt{5}} = \cfrac{2x}{\sqrt{5}}\cdot\cfrac{\sqrt{5}}{\sqrt{5}}
# $$
#
# $$
# A = \cfrac{b\cdot x}{2} = \cfrac{\cfrac{2\sqrt{5}\cdot x}{5}\cdot x}{2} = \cfrac{\sqrt{5}\,x^2}{5}
# $$
